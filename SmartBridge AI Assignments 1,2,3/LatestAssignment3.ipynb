#   inflating: train_data/train_data/jglowl/_D32_10285.jpg
#   inflating: train_data/train_data/jglowl/_D32_10578.jpg
#   inflating: train_data/train_data/jglowl/_D32_10583.jpg
#   inflating: train_data/train_data/lbicrw/100_4037.JPG
#   inflating: train_data/train_data/lbicrw/100_4912.JPG
#   inflating: train_data/train_data/lbicrw/100_4913.JPG
#   inflating: train_data/train_data/lbicrw/100_4914.JPG
#   inflating: train_data/train_data/lbicrw/100_4915.JPG
#   inflating: train_data/train_data/lbicrw/100_4916.JPG
#   inflating: train_data/train_data/mgprob/100_5587.JPG
#   inflating: train_data/train_data/mgprob/100_5588.JPG
#   inflating: train_data/train_data/mgprob/100_5589.JPG
#   inflating: train_data/train_data/mgprob/100_5590.JPG
#   inflating: train_data/train_data/mgprob/100_5592.JPG
#   inflating: train_data/train_data/mgprob/100_5762.JPG
#   inflating: train_data/train_data/rebimg/100_5744.JPG
#   inflating: train_data/train_data/rebimg/100_5745.JPG
#   inflating: train_data/train_data/rebimg/100_5746.JPG
#   inflating: train_data/train_data/rebimg/100_5748.JPG
#   inflating: train_data/train_data/rebimg/100_5749.JPG
#   inflating: train_data/train_data/rebimg/100_5750.JPG
#   inflating: train_data/train_data/rebimg/100_5751.JPG
#   inflating: train_data/train_data/rebimg/100_5752.JPG
#   inflating: train_data/train_data/rebimg/100_5754.JPG
#   inflating: train_data/train_data/rebimg/100_5755.JPG
#   inflating: train_data/train_data/wcrsrt/100_4452.JPG
#   inflating: train_data/train_data/wcrsrt/100_4453.JPG
#   inflating: train_data/train_data/wcrsrt/100_4454.JPG
#   inflating: train_data/train_data/wcrsrt/100_4455.JPG
#   inflating: train_data/train_data/wcrsrt/100_4456.JPG
#   inflating: train_data/train_data/wcrsrt/100_4457.JPG
#   inflating: train_data/train_data/wcrsrt/100_4458.JPG
#   inflating: train_data/train_data/wcrsrt/100_4459.JPG
#   inflating: train_data/train_data/wcrsrt/100_4460.JPG
#   inflating: train_data/train_data/wcrsrt/100_4461.JPG

# %%
#Data augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_gen = ImageDataGenerator(rescale=(1./255),horizontal_flip=True,shear_range=0.2)
test_gen = ImageDataGenerator(rescale=(1./255))

# %%
train = train_gen.flow_from_directory('/content/train_data/train_data',
                                      target_size=(120,120),
                                      class_mode='categorical',
                                      batch_size=8
                                      )
test = test_gen.flow_from_directory('/content/test_data/test_data',
                                     target_size=(120,120),
                                     class_mode='categorical',
                                     batch_size=8
                                     )
# Out:
# Found 150 images belonging to 16 classes.
# Found 157 images belonging to 16 classes.

# %%
train.class_indices
# Out:
# {'blasti': 0,
#  'bonegl': 1,
#  'brhkyt': 2,
#  'cbrtsh': 3,
#  'cmnmyn': 4,
#  'gretit': 5,
#  'hilpig': 6,
#  'himbul': 7,
#  'himgri': 8,
#  'hsparo': 9,
#  'indvul': 10,
#  'jglowl': 11,
#  'lbicrw': 12,
#  'mgprob': 13,
#  'rebimg': 14,
#  'wcrsrt': 15}

# %%
#CNN Model
from tensorflow.keras.layers import Convolution2D,MaxPooling2D,Flatten,Dense
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(Convolution2D(20,(3,3),activation='relu',input_shape=(120,120,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(45,activation='relu'))
model.add(Dense(16,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train,batch_size=8,validation_data=test,epochs=10)
# Out:
# Epoch 1/10
# 19/19 [==============================] - 130s 7s/step - loss: 4.0066 - accuracy: 0.1067 - val_loss: 2.7499 - val_accuracy: 0.1465
# Epoch 2/10
# 19/19 [==============================] - 80s 4s/step - loss: 2.6417 - accuracy: 0.1267 - val_loss: 2.7652 - val_accuracy: 0.0764
# Epoch 3/10
# 19/19 [==============================] - 82s 4s/step - loss: 2.5655 - accuracy: 0.2000 - val_loss: 2.8046 - val_accuracy: 0.0573
# Epoch 4/10
# 19/19 [==============================] - 80s 4s/step - loss: 2.4829 - accuracy: 0.1933 - val_loss: 2.8533 - val_accuracy: 0.1210
# Epoch 5/10
# 19/19 [==============================] - 116s 6s/step - loss: 2.4970 - accuracy: 0.1933 - val_loss: 2.7781 - val_accuracy: 0.1338
# Epoch 6/10
# 19/19 [==============================] - 82s 4s/step - loss: 2.3477 - accuracy: 0.2267 - val_loss: 2.7454 - val_accuracy: 0.1720
# Epoch 7/10
# 19/19 [==============================] - 84s 5s/step - loss: 2.2403 - accuracy: 0.2600 - val_loss: 2.6981 - val_accuracy: 0.1465
# Epoch 8/10
# 19/19 [==============================] - 84s 5s/step - loss: 2.1392 - accuracy: 0.2733 - val_loss: 2.7566 - val_accuracy: 0.1720
# Epoch 9/10
# 19/19 [==============================] - 85s 5s/step - loss: 2.0583 - accuracy: 0.2800 - val_loss: 2.7337 - val_accuracy: 0.1592
# Epoch 10/10
# 19/19 [==============================] - 81s 4s/step - loss: 1.8858 - accuracy: 0.3000 - val_loss: 2.7395 - val_accuracy: 0.1465

# %%
model.save('birdWeights.h5')

# %%
#Testing

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# %%
img = image.load_img('/content/crow.jpg', target_size=(120,120))

# %%
img = image.img_to_array(img)
img
# Out:
# array([[[126., 110.,  87.],
#         [116., 100.,  77.],
#         [110.,  94.,  71.],
#         ...,
#         [116.,  99.,  79.],
#         [120., 104.,  81.],
#         [114.,  97.,  77.]],
#
#        [[134., 120.,  94.],
#         [119., 103.,  78.],
#         [114., 100.,  74.],
#         ...,
#         [123., 105.,  83.],
#         [119., 103.,  80.],
#         [113.,  96.,  78.]],
#
#        [[132., 117.,  94.],
#         [117., 102.,  79.],
#         [115., 100.,  81.],
#         ...,
#         [123., 106.,  80.],
#         [110.,  93.,  73.],
#         [108.,  93.,  74.]],
#
#        ...,
#
#        [[230., 230., 230.],
#         [236., 236., 236.],
#         [231., 229., 230.],
#         ...,
#         [ 96.,  97.,  39.],
#         [ 69., 103.,  17.],
#         [ 71.,  89.,  27.]],
#
#        [[229., 229., 227.],
#         [232., 231., 229.],
#         [228., 228., 226.],
#         ...,
#         [ 87.,  81.,  29.],
#         [ 74., 121.,  19.],
#         [ 52.,  37.,   8.]],
#
#        [[233., 233., 233.],
#         [230., 230., 230.],
#         [231., 231., 231.],
#         ...,
#         [ 73.,  62.,  30.],
#         [ 41.,  46.,  16.],
#         [ 38.,  28.,   3.]]], dtype=float32)

# %%
img=np.expand_dims(img,axis=0)
img
# Out:
# array([[[[126., 110.,  87.],
#          [116., 100.,  77.],
#          [110.,  94.,  71.],
#          ...,
#          [116.,  99.,  79.],
#          [120., 104.,  81.],
#          [114.,  97.,  77.]],
#
#         [[134., 120.,  94.],
#          [119., 103.,  78.],
#          [114., 100.,  74.],
#          ...,
#          [123., 105.,  83.],
#          [119., 103.,  80.],
#          [113.,  96.,  78.]],
#
#         [[132., 117.,  94.],
#          [117., 102.,  79.],
#          [115., 100.,  81.],
#          ...,
#          [123., 106.,  80.],
#          [110.,  93.,  73.],
#          [108.,  93.,  74.]],
#
#         ...,
#
#         [[230., 230., 230.],
#          [236., 236., 236.],
#          [231., 229., 230.],
#          ...,
#          [ 96.,  97.,  39.],
#          [ 69., 103.,  17.],
#          [ 71.,  89.,  27.]],
#
#         [[229., 229., 227.],
#          [232., 231., 229.],
#          [228., 228., 226.],
#          ...,
#          [ 87.,  81.,  29.],
#          [ 74., 121.,  19.],
#          [ 52.,  37.,   8.]],
#
#         [[233., 233., 233.],
#          [230., 230., 230.],
#          [231., 231., 231.],
#          ...,
#          [ 73.,  62.,  30.],
#          [ 41.,  46.,  16.],
#          [ 38.,  28.,   3.]]]], dtype=float32)

# %%
model.predict(img)
# Out:
# 1/1 [==============================] - 0s 116ms/step
# array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.7052346e-17]],
#       dtype=float32)

# %%
np.argmax(model.predict(img))
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 12

# %%
# Testing 1
img1 = image.load_img('/content/owl.jpg',target_size=(120,120))
img1 = image.img_to_array(img1)
img1 = np.expand_dims(img1,axis=0)
pred = np.argmax(model.predict(img1))
print(pred)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 3

# %%
# Testing 2
img2 = image.load_img('/content/crow.jpg',target_size=(120,120))
img2 = image.img_to_array(img2)
img2 = np.expand_dims(img2,axis=0)
pred = np.argmax(model.predict(img2))
print(pred)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 12

# %%
# Testing 3
img3 = image.load_img('/content/pigeon.jpg',target_size=(120,120))
img3 = image.img_to_array(img3)
img3 = np.expand_dims(img3,axis=0)
pred = np.argmax(model.predict(img3))
print(pred)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 3

# %%
# Model Tuning (Adding feature extraction layers)

# %%
model = Sequential()
model.add(Convolution2D(12,(3,3),activation='relu',input_shape=(120, 120, 3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Convolution2D(24,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Convolution2D(36,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(62,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(16,activation='relu'))
model.add(Dense(16,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 118, 118, 12)      336
#
#  max_pooling2d_4 (MaxPooling  (None, 59, 59, 12)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 57, 57, 24)        2616
#
#  max_pooling2d_5 (MaxPooling  (None, 28, 28, 24)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 26, 26, 36)        7812
#
#  max_pooling2d_6 (MaxPooling  (None, 13, 13, 36)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 6084)              0
#
#  dense_6 (Dense)             (None, 62)                377270
#
#  dense_7 (Dense)             (None, 32)                2016
#
#  dense_8 (Dense)             (None, 16)                528
#
#  dense_9 (Dense)             (None, 16)                272
#
# =================================================================
# Total params: 390,850
# Trainable params: 390,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train,batch_size=8,validation_data=test,epochs=50)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 87s 5s/step - loss: 2.7799 - accuracy: 0.0800 - val_loss: 2.7682 - val_accuracy: 0.1083
# Epoch 2/50
# 19/19 [==============================] - 118s 6s/step - loss: 2.7636 - accuracy: 0.1133 - val_loss: 2.7441 - val_accuracy: 0.1338
# Epoch 3/50
# 19/19 [==============================] - 82s 4s/step - loss: 2.7311 - accuracy: 0.1600 - val_loss: 2.7243 - val_accuracy: 0.1210
# Epoch 4/50
# 19/19 [==============================] - 85s 5s/step - loss: 2.6094 - accuracy: 0.2067 - val_loss: 2.6892 - val_accuracy: 0.1529
# Epoch 5/50
# 19/19 [==============================] - 83s 5s/step - loss: 2.6627 - accuracy: 0.1600 - val_loss: 2.6904 - val_accuracy: 0.1338
# Epoch 6/50
# 19/19 [==============================] - 82s 4s/step - loss: 2.4893 - accuracy: 0.1933 - val_loss: 2.6784 - val_accuracy: 0.1656
# Epoch 7/50
# 19/19 [==============================] - 83s 5s/step - loss: 2.4048 - accuracy: 0.2000 - val_loss: 2.7172 - val_accuracy: 0.1401
# Epoch 8/50
# 19/19 [==============================] - 82s 4s/step - loss: 2.3604 - accuracy: 0.2400 - val_loss: 2.7037 - val_accuracy: 0.1529
# Epoch 9/50
# 19/19 [==============================] - 84s 5s/step - loss: 2.3213 - accuracy: 0.2400 - val_loss: 2.7560 - val_accuracy: 0.1146
# Epoch 10/50
# 19/19 [==============================] - 82s 4s/step - loss: 2.2660 - accuracy: 0.2467 - val_loss: 2.6759 - val_accuracy: 0.1720
# Epoch 11/50
# 19/19 [==============================] - 84s 5s/step - loss: 2.2105 - accuracy: 0.2600 - val_loss: 2.6766 - val_accuracy: 0.2038
# Epoch 12/50
# 19/19 [==============================] - 84s 4s/step - loss: 2.0404 - accuracy: 0.2933 - val_loss: 2.8339 - val_accuracy: 0.1529
# Epoch 13/50
# 19/19 [==============================] - 117s 6s/step - loss: 1.9755 - accuracy: 0.3267 - val_loss: 2.8968 - val_accuracy: 0.2229
# Epoch 14/50
# 19/19 [==============================] - 84s 4s/step - loss: 1.7988 - accuracy: 0.4467 - val_loss: 2.8821 - val_accuracy: 0.2293
# Epoch 15/50
# 19/19 [==============================] - 82s 4s/step - loss: 1.7282 - accuracy: 0.4467 - val_loss: 2.7922 - val_accuracy: 0.2038
# Epoch 16/50
# 19/19 [==============================] - 83s 4s/step - loss: 1.5919 - accuracy: 0.5000 - val_loss: 3.0399 - val_accuracy: 0.1847
# Epoch 17/50
# 19/19 [==============================] - 82s 4s/step - loss: 1.4734 - accuracy: 0.5267 - val_loss: 3.0417 - val_accuracy: 0.1911
# Epoch 18/50
# 19/19 [==============================] - 82s 4s/step - loss: 1.4300 - accuracy: 0.5667 - val_loss: 2.9149 - val_accuracy: 0.2675
# Epoch 19/50
# 19/19 [==============================] - 84s 5s/step - loss: 1.2507 - accuracy: 0.6067 - val_loss: 3.0889 - val_accuracy: 0.2675
# Epoch 20/50
# 19/19 [==============================] - 118s 6s/step - loss: 1.2379 - accuracy: 0.6133 - val_loss: 2.9657 - val_accuracy: 0.2548
# Epoch 21/50
# 19/19 [==============================] - 84s 5s/step - loss: 1.1547 - accuracy: 0.6200 - val_loss: 3.3761 - val_accuracy: 0.2357
# Epoch 22/50
# 19/19 [==============================] - 82s 4s/step - loss: 1.0423 - accuracy: 0.6533 - val_loss: 3.5825 - val_accuracy: 0.2357
# Epoch 23/50
# 19/19 [==============================] - 82s 4s/step - loss: 0.9717 - accuracy: 0.7067 - val_loss: 3.3486 - val_accuracy: 0.2229
# Epoch 24/50
# 19/19 [==============================] - 82s 4s/step - loss: 0.7699 - accuracy: 0.7400 - val_loss: 3.7227 - val_accuracy: 0.2803
# Epoch 25/50
# 19/19 [==============================] - 118s 6s/step - loss: 0.6090 - accuracy: 0.8000 - val_loss: 3.9418 - val_accuracy: 0.2548
# Epoch 26/50
# 19/19 [==============================] - 82s 4s/step - loss: 0.5823 - accuracy: 0.7800 - val_loss: 4.1278 - val_accuracy: 0.2357
# Epoch 27/50
# 19/19 [==============================] - 84s 5s/step - loss: 0.8623 - accuracy: 0.7067 - val_loss: 3.8660 - val_accuracy: 0.2293
# Epoch 28/50
# 19/19 [==============================] - 83s 5s/step - loss: 0.7217 - accuracy: 0.7600 - val_loss: 3.6518 - val_accuracy: 0.2803
# Epoch 29/50
# 19/19 [==============================] - 83s 5s/step - loss: 0.4976 - accuracy: 0.8600 - val_loss: 4.3361 - val_accuracy: 0.2803
# Epoch 30/50
# 19/19 [==============================] - 82s 4s/step - loss: 0.4403 - accuracy: 0.8200 - val_loss: 4.6633 - val_accuracy: 0.3248
# Epoch 31/50
# 19/19 [==============================] - 83s 5s/step - loss: 0.5661 - accuracy: 0.7867 - val_loss: 4.5717 - val_accuracy: 0.2420
# Epoch 32/50
# 19/19 [==============================] - 82s 4s/step - loss: 0.5837 - accuracy: 0.8200 - val_loss: 4.5493 - val_accuracy: 0.2484
# Epoch 33/50
# 19/19 [==============================] - 83s 4s/step - loss: 0.6358 - accuracy: 0.8133 - val_loss: 4.4468 - val_accuracy: 0.2675
# Epoch 34/50
# 19/19 [==============================] - 82s 4s/step - loss: 0.5339 - accuracy: 0.8267 - val_loss: 4.4378 - val_accuracy: 0.2484
# Epoch 35/50
# 19/19 [==============================] - 82s 4s/step - loss: 0.3343 - accuracy: 0.9000 - val_loss: 4.5962 - val_accuracy: 0.2994
# Epoch 36/50
# 19/19 [==============================] - 84s 5s/step - loss: 0.3352 - accuracy: 0.8867 - val_loss: 5.3767 - val_accuracy: 0.2357
# Epoch 37/50
# 19/19 [==============================] - 83s 4s/step - loss: 0.3643 - accuracy: 0.8600 - val_loss: 5.1137 - val_accuracy: 0.2166
# Epoch 38/50
# 19/19 [==============================] - 83s 5s/step - loss: 0.2199 - accuracy: 0.9267 - val_loss: 5.1970 - val_accuracy: 0.2930
# Epoch 39/50
# 19/19 [==============================] - 82s 4s/step - loss: 0.2227 - accuracy: 0.9000 - val_loss: 5.7226 - val_accuracy: 0.2675
# Epoch 40/50
# 19/19 [==============================] - 84s 5s/step - loss: 0.2397 - accuracy: 0.9533 - val_loss: 5.6524 - val_accuracy: 0.2803
# Epoch 41/50
# 19/19 [==============================] - 82s 5s/step - loss: 0.1532 - accuracy: 0.9800 - val_loss: 5.8767 - val_accuracy: 0.2994
# Epoch 42/50
# 19/19 [==============================] - 86s 5s/step - loss: 0.1298 - accuracy: 0.9600 - val_loss: 5.9302 - val_accuracy: 0.2866
# Epoch 43/50
# 19/19 [==============================] - 118s 6s/step - loss: 0.0997 - accuracy: 0.9800 - val_loss: 6.3952 - val_accuracy: 0.2739
# Epoch 44/50
# 19/19 [==============================] - 82s 4s/step - loss: 0.2258 - accuracy: 0.9533 - val_loss: 6.4997 - val_accuracy: 0.2293
# Epoch 45/50
# 19/19 [==============================] - 82s 4s/step - loss: 0.2667 - accuracy: 0.9200 - val_loss: 6.0152 - val_accuracy: 0.2739
# Epoch 46/50
# 19/19 [==============================] - 82s 4s/step - loss: 0.2170 - accuracy: 0.9400 - val_loss: 6.3891 - val_accuracy: 0.2803
# Epoch 47/50
# 19/19 [==============================] - 119s 7s/step - loss: 0.3612 - accuracy: 0.9000 - val_loss: 6.9113 - val_accuracy: 0.1975
# Epoch 48/50
# 19/19 [==============================] - 82s 4s/step - loss: 0.3499 - accuracy: 0.8800 - val_loss: 5.7338 - val_accuracy: 0.2357
# Epoch 49/50
# 19/19 [==============================] - 82s 5s/step - loss: 0.1778 - accuracy: 0.9533 - val_loss: 5.5808 - val_accuracy: 0.2739
# Epoch 50/50
# 19/19 [==============================] - 82s 4s/step - loss: 0.2146 - accuracy: 0.9533 - val_loss: 5.7224 - val_accuracy: 0.2675

# %%
# Testing 1
img1 = image.load_img('/content/owl.jpg',target_size=(120,120))
img1 = image.img_to_array(img1)
img1 = np.expand_dims(img1,axis=0)
pred = np.argmax(model.predict(img1))
print(pred)
# Out:
# 1/1 [==============================] - 0s 153ms/step
# 14

# %%
# Testing 2
img2 = image.load_img('/content/crow.jpg',target_size=(120,120))
img2 = image.img_to_array(img2)
img2 = np.expand_dims(img2,axis=0)
pred = np.argmax(model.predict(img2))
print(pred)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 14

# %%
# Testing 3
img3 = image.load_img('/content/pigeon.jpg',target_size=(120,120))
img3 = image.img_to_array(img3)
img3 = np.expand_dims(img3,axis=0)
pred = np.argmax(model.predict(img3))
print(pred)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 7

# %%
# Model tuning (with dropout, batch normalization & early stopping)

# %%
from tensorflow.keras.layers import BatchNormalization, Dropout

# %%
model = Sequential()
model.add(Convolution2D(12,(3,3),activation='relu',input_shape=(120, 120, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Convolution2D(24,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Convolution2D(36,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(62,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))
model.add(Dense(32,activation='relu'))
model.add(Dense(16,activation='relu'))
model.add(Dense(16,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 118, 118, 12)      336
#
#  batch_normalization (BatchN  (None, 118, 118, 12)     48
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 59, 59, 12)       0
#  )
#
#  dropout (Dropout)           (None, 59, 59, 12)        0
#
#  conv2d_1 (Conv2D)           (None, 57, 57, 24)        2616
#
#  batch_normalization_1 (Batc  (None, 57, 57, 24)       96
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 28, 28, 24)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 28, 28, 24)        0
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 36)        7812
#
#  batch_normalization_2 (Batc  (None, 26, 26, 36)       144
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 36)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 13, 13, 36)        0
#
#  flatten (Flatten)           (None, 6084)              0
#
#  dense (Dense)               (None, 62)                377270
#
#  batch_normalization_3 (Batc  (None, 62)               248
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 62)                0
#
#  dense_1 (Dense)             (None, 32)                2016
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 16)                272
#
# =================================================================
# Total params: 391,386
# Trainable params: 391,118
# Non-trainable params: 268
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='accuracy',patience=8)

# %%
model.fit(train,batch_size=8,validation_data=test,epochs=50,callbacks=early_stop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e25de0ccc4bc> in <cell line: 1>()
# ----> 1 model.fit(train,batch_size=8,validation_data=test,epochs=50,callbacks=early_stop)
#
# NameError: name 'model' is not defined

# %%
# Testing 1
img1 = image.load_img('/content/owl.jpg',target_size=(120,120))
img1 = image.img_to_array(img1)
img1 = np.expand_dims(img1,axis=0)
pred = np.argmax(model.predict(img1))
print(pred)

# %%
# Testing 2
img2 = image.load_img('/content/crow.jpg',target_size=(120,120))
img2 = image.img_to_array(img2)
img2 = np.expand_dims(img2,axis=0)
pred = np.argmax(model.predict(img2))
print(pred)

# %%
# Testing 3
img3 = image.load_img('/content/pigeon.jpg',target_size=(120,120))
img3 = image.img_to_array(img3)
img3 = np.expand_dims(img3,axis=0)
pred = np.argmax(model.predict(img3))
print(pred)
